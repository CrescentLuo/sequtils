# %%
import pysam 
import pandas as pd

# %%
df = pd.read_csv("/Users/zluo/TestData/GENCODE/GRCh38/gencode.v31.primary_assembly.protein_coding.exon.srt.bed",sep='\t', names=['chrom','start','end','name','score','strand'])
# Out:
#        chrom     start       end                       name score strand
# 0       chr1     65519     65573    ENSG00000186092.6_OR4F5  exon      +
# 1       chr1    925921    926013  ENSG00000187634.12_SAMD11  exon      +
# 2       chr1    930154    930336  ENSG00000187634.12_SAMD11  exon      +
# 3       chr1    931038    931089  ENSG00000187634.12_SAMD11  exon      +
# 4       chr1    935771    935805  ENSG00000187634.12_SAMD11  exon      +
# ...      ...       ...       ...                        ...   ...    ...
# 213117  chrY  25038808  25038914    ENSG00000185894.8_BPY2C  exon      -
# 213118  chrY  25041768  25041886    ENSG00000185894.8_BPY2C  exon      -
# 213119  chrY  25043945  25044064    ENSG00000185894.8_BPY2C  exon      -
# 213120  chrY  25048473  25048610    ENSG00000185894.8_BPY2C  exon      -
# 213121  chrY  25051675  25051798    ENSG00000185894.8_BPY2C  exon      -
#
# [213122 rows x 6 columns]

# %%
fa = pysam.FastaFile("/Users/zluo/TestData/GENCODE/GRCh38/Sequence/GRCh38.p13.genome.fa")
